# %% [markdown]
# # DATSET COLLECTION

# %%
import cv2
import os
import time
import uuid

# %%
IMAGES_PATH='Tensorflow/workspace/images/collectedimages'

# %%
labels={'hello','thanks','yes','no','iloveyou','sign','language','namaste','bye','practice','college','sorry','good','bad','teacher','week','wednesday','one','two','three'}
number_imgs=25

# %%
for label in labels:
    # !mkdir {'Tensorflow\workspace\images\collectedimages\\'+label}
    cap=cv2.VideoCapture(0)
    print("Collecting images for {}".format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('collecting image {}'.format(imgnum))
        ret,frame=cap.read()
        imgname=os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if 0xFF==ord('q'):
            break
    cap.release()
# Out:
# Collecting images for bye
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for one
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for teacher
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for sorry
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for wednesday
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for bad
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for two
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for thanks
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for no
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for week
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for sign
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for language
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for hello
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for namaste
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for three
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for college
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for practice
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for iloveyou
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for good
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
# Collecting images for yes
# collecting image 0
# collecting image 1
# collecting image 2
# collecting image 3
# collecting image 4
# collecting image 5
# collecting image 6
# collecting image 7
# collecting image 8
# collecting image 9
# collecting image 10
# collecting image 11
# collecting image 12
# collecting image 13
# collecting image 14
# collecting image 15
# collecting image 16
# collecting image 17
# collecting image 18
# collecting image 19
# collecting image 20
# collecting image 21
# collecting image 22
# collecting image 23
# collecting image 24
